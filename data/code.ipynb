# %% [markdown]
# <a href="https://colab.research.google.com/github/Fatimhprog/AI-Generated-Text-Detection-MSIS822/blob/main/data/code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from datasets import load_dataset

dataset = load_dataset("KFUPM-JRCAI/arabic-generated-abstracts")
# Out:
# README.md:   0%|          | 0.00/8.10k [00:00<?, ?B/s]
# data/by_polishing-00000-of-00001.parquet: reconstructing file:   0%|          |  0.00B / 8.49MB
# data/by_polishing-00000-of-00001.parquet: downloading bytes:           |  0.00B
# data/from_title-00000-of-00001.parquet: reconstructing file:   0%|          |  0.00B / 6.90MB
# data/from_title-00000-of-00001.parquet: downloading bytes:           |  0.00B
# data/from_title_and_content-00000-of-000(…): reconstructing file:   0%|          |  0.00B / 7.01MB
# data/from_title_and_content-00000-of-000(…): downloading bytes:           |  0.00B
# ...
# Generating from_title_and_content split:   0%|          | 0/2574 [00:00<?, ? examples/s]

# %%
df = dataset["by_polishing"].to_pandas()

print(df.columns)
print(df.dtypes)
df.head()
# Out:
# Index(['original_abstract', 'allam_generated_abstract',
#        'jais_generated_abstract', 'llama_generated_abstract',
#        'openai_generated_abstract'],
#       dtype='object')
# original_abstract            object
# allam_generated_abstract     object
# jais_generated_abstract      object
# llama_generated_abstract     object
# openai_generated_abstract    object
# dtype: object
#                                    original_abstract  \
# 0  كثيرا ما ارتبطت المصادر التاريخية في الأندلس خ...
# 1  يعد العامل الثقافي احد ابرز الاسباب التي يعزى ...
# 2  شكلت تلك الجهود والمساعي الرائدة التي قام بها ...
# 3  يقوم المقال على اشكالية الضرائب الغير شرعية في...
# 4  تتفق المصادر التاريخية المتوفرة حول موضوع تطور...
#
#                             allam_generated_abstract  \
# 0  يتناول هذا البحث موضوع التعليم بين النساء الأن...
# 1  يتناول هذا البحث دراسة انهيار دولة الموحدين من...
# 2  هدفت هذه الدراسة إلى تسليط الضوء على جهود قادة...
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

df = dataset["by_polishing"].to_pandas()

human_rows = [{"text": row["original_abstract"], "label": "human"}
              for _, row in df.iterrows()]

ai_rows = []
for _, row in df.iterrows():
    ai_rows.append({"text": row["allam_generated_abstract"], "label": "ai_generated"})
    ai_rows.append({"text": row["jais_generated_abstract"], "label": "ai_generated"})
    ai_rows.append({"text": row["llama_generated_abstract"], "label": "ai_generated"})
    ai_rows.append({"text": row["openai_generated_abstract"], "label": "ai_generated"})

df_labels = pd.DataFrame(human_rows + ai_rows)

# %%
df_labels["label"].value_counts()
# Out:
# label
# ai_generated    11404
# human            2851
# Name: count, dtype: int64

# %%
df_labels.isnull().sum()
# Out:
# text     0
# label    0
# dtype: int64

# %%
df_labels[df_labels.duplicated()]
# Out:
# Empty DataFrame
# Columns: [text, label]
# Index: []

# %%
df_labels.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_labels["label"].value_counts()
# Out:
# label
# ai_generated    11404
# human            2851
# Name: count, dtype: int64
